# %% [markdown]
# <a href="https://colab.research.google.com/github/polatsena/Deep-Neural-Network-for-Image-Classification--Application/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/nadinezab/kc-house-prices-prediction/blob/master/kc-house-prices.ipynb
#
# burda sunum da yapmış yapan kişi data set açıklaası vs de var bakılabilir.

# %%
#Gerekli Kütüphaneler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
df=pd.read_csv("kc_house_data.csv")
df.head() #verinin ilk 5 satırını görme
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.info() #Değişken tipleri hakkında bilgi
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# # EDA KEŞİFSEL VERİ ANALİZİ

# %%
df.date.max()[0:8]
# Out:
# '20150527'

# %%
df.date.min()[0:8]
# Out:
# '20140502'

# %%
print("King County'deki satış fiyatları",df.date.min()[0:8],"ile",df.date.max()[0:8],"tarihleri arasındadır.")
# Out:
# King County'deki satış fiyatları 20140502 ile 20150527 tarihleri arasındadır.

# %%
# Fiyat Dağılımları Histogramı
sns.distplot(df["price"])
#histogramı incelediğimizde satış fiyatının sağa çarpık olduğunu yani normal dağılmadığını söyleyebiliriz. En çok satış yapılan fiyat ortalama fiyattan daha çoktur diyebiliriz.
# Out:
# <ipython-input-3-82bc75a46e7f>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["price"])
# <Axes: xlabel='price', ylabel='Density'>

# %%
# yatak odası sayısı ile fiyatların ilişkisi
grpby_bedrooms_df = df[["price", "bedrooms"]].groupby(by = "bedrooms", as_index = False)
grpby_bedrooms_df = grpby_bedrooms_df.mean()
grpby_bedrooms_df.head()
# Out:
#    bedrooms          price
# 0         0  409503.846154
# 1         1  317642.884422
# 2         2  401372.681884
# 3         3  466232.078481
# 4         4  635419.504214

# %%
f, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10))
ax1.set(yscale = "log")
sns.stripplot(x = "bedrooms", y = "price", data = df, ax = ax1, jitter=True, palette="Blues_d")
sns.barplot(x = "bedrooms", y = "price", data = grpby_bedrooms_df, ax = ax2, palette="Blues_d")
# Out:
# <ipython-input-8-ef046db3355e>:3: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x = "bedrooms", y = "price", data = df, ax = ax1, jitter=True, palette="Blues_d")
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
df["date"].sort_values()
# Out:
# 16768    20140502T000000
# 9596     20140502T000000
# 9587     20140502T000000
# 20602    20140502T000000
# 11577    20140502T000000
#               ...
# 7898     20150514T000000
# 928      20150514T000000
# 5637     20150515T000000
# 13053    20150524T000000
# 16594    20150527T000000
# Name: date, Length: 21613, dtype: object

# %% [markdown]
# https://github.com/BhagyeshVikani/House-Sales-in-King-County-USA/blob/master/Want%20to%20Buy%20a%20house%3F.ipynb

# %% [markdown]
# https://github.com/galkampel/HouseSales/blob/main/EDA.ipynb

# %% [markdown]
# # **MODELLING**

# %%
# Makine Öğrenmesi Modellemesi İçin Gerekli Araçlar
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
#Pairplot kullanarak en iyi özellikleri ve fiyatı kontrol etme.
## Pairplot
##Scatterplot
sorted_features = ['grade','lat','sqft_living','sqft_above','waterfront','view']
sns.set(font_scale=2.2)
g = sns.pairplot(df[sorted_features] ,size=5)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sorted_features = ['grade','lat','sqft_living','sqft_above','waterfront','view']
best_feature_matrix = df[sorted_features]
best_feature_matrix
# Out:
#        grade      lat  sqft_living  sqft_above  waterfront  view
# 0          7  47.5112         1180        1180           0     0
# 1          7  47.7210         2570        2170           0     0
# 2          6  47.7379          770         770           0     0
# 3          7  47.5208         1960        1050           0     0
# 4          8  47.6168         1680        1680           0     0
# ...      ...      ...          ...         ...         ...   ...
# 21608      8  47.6993         1530        1530           0     0
# 21609      8  47.5107         2310        2310           0     0
# 21610      7  47.5944         1020        1020           0     0
# 21611      8  47.5345         1600        1600           0     0
# 21612      7  47.5941         1020        1020           0     0
#
# [21613 rows x 6 columns]

# %%
#train_test_split kullanarak, verileri izleme veri kümesi ve test veri kümeleri olarak ayıralım.
lable_vector = df['price']
X_train, X_test, y_train, y_test = train_test_split(best_feature_matrix, lable_vector, test_size=0.3, random_state=3)

# %% [markdown]
# KARAR AĞACI

# %%
my_decisiontree = DecisionTreeClassifier()
my_decisiontree.fit(X_train, y_train)
y_predict_dt = my_decisiontree.predict(X_test)
score_dt= accuracy_score(y_test, y_predict_dt)
print("Decision tree accuracy>>>>",score_dt)
# Out:
# Decision tree accuracy>>>> 0.007557063541024059

# %%
KNN
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-26e9efe9dfdb> in <cell line: 1>()
# ----> 1 KNN
#
# NameError: name 'KNN' is not defined

# %%
from sklearn.neighbors import KNeighborsClassifier
k = 25 #komşu sayısı
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train, y_train)
y_predict_knn = knn.predict(X_test)
score_knn = accuracy_score(y_test, y_predict_knn)
print("KNN accuracy>>>>",score_knn)
# Out:
# KNN accuracy>>>> 0.005243676742751388

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
my_RandomForest = RandomForestClassifier(n_estimators = 10, bootstrap = True, random_state=2)
my_RandomForest.fit(X_train,y_train)
y_predict_rf=my_RandomForest.predict(X_test)
score_rf=accuracy_score(y_test, y_predict_rf)
print("Accuracy for Random Forest>>>>> ",score_rf)
# Out:
# Accuracy for Random Forest>>>>>  0.010333127698951264

# %%
from sklearn.linear_model import LogisticRegression
# https://github.com/brijshah27/House-Sales-Prediction/blob/master/predict_sales.ipynb

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_squared_error
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from matplotlib import style
from sklearn.decomposition import PCA
import matplotlib.cm as cm
from sklearn.preprocessing import PolynomialFeatures
from matplotlib import *

# %%
my_linear = LinearRegression()

# %% [markdown]
# # Yeni Bölüm

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df2= df[["price",'bedrooms','bathrooms','view','grade','sqft_above','lat','long']] #kullanacağımız değişkenleri seçtik

# %% [markdown]
# *   Bağımlı değişken(yanıt değişkeni) : price (y)
# *   Bağımsız değişkenler : bedrooms, bathrooms,view(kategorik), grade , sqft_above, lat, long

# %%
df2.head()
# Out:
#       price  bedrooms  bathrooms  view  grade  sqft_above      lat     long
# 0  221900.0         3       1.00     0      7        1180  47.5112 -122.257
# 1  538000.0         3       2.25     0      7        2170  47.7210 -122.319
# 2  180000.0         2       1.00     0      6         770  47.7379 -122.233
# 3  604000.0         4       3.00     0      7        1050  47.5208 -122.393
# 4  510000.0         3       2.00     0      8        1680  47.6168 -122.045

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   price       21613 non-null  float64
#  1   bedrooms    21613 non-null  int64
#  2   bathrooms   21613 non-null  float64
#  3   view        21613 non-null  int64
#  4   grade       21613 non-null  int64
#  5   sqft_above  21613 non-null  int64
#  6   lat         21613 non-null  float64
#  7   long        21613 non-null  float64
# dtypes: float64(4), int64(4)
# memory usage: 1.3 MB

# %%
#tip dönüşümleri
df2["price"]=df2["price"].astype(int)
df2["bathrooms"]=df2["bathrooms"].astype(int)
# Out:
# <ipython-input-33-9ca1084a77d2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["price"]=df2["price"].astype(int)
# <ipython-input-33-9ca1084a77d2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["bathrooms"]=df2["bathrooms"].astype(int)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   price       21613 non-null  int64
#  1   bedrooms    21613 non-null  int64
#  2   bathrooms   21613 non-null  int64
#  3   view        21613 non-null  int64
#  4   grade       21613 non-null  int64
#  5   sqft_above  21613 non-null  int64
#  6   lat         21613 non-null  float64
#  7   long        21613 non-null  float64
# dtypes: float64(2), int64(6)
# memory usage: 1.3 MB

# %% [markdown]
# bağımlı değişken ile diğer değişkenlerin ilişkisini inceleme

# %%
# Set the palette
sns.color_palette("flare", as_cmap=True)
# Create the pairplot with a title
sns.pairplot(df2)

# %%
#Modelimizdeki hedef değişken 'price' olduğu için onun dağılımına bakıyoruz ve veri setinin geri kalanından ayırıyoruz.(yukarıda histogram grafiği ile baktık.)
y=df2.price
sns.distplot(y)
plt.show()
# Out:
# <ipython-input-47-ed8794cb58cf>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y)

# %%
X = df2.drop(['price'], axis=1) #bağımsız değişkenlerimiz

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bedrooms    21613 non-null  int64
#  1   bathrooms   21613 non-null  int64
#  2   view        21613 non-null  int64
#  3   grade       21613 non-null  int64
#  4   sqft_above  21613 non-null  int64
#  5   lat         21613 non-null  float64
#  6   long        21613 non-null  float64
#  7   0           21613 non-null  uint8
#  8   1           21613 non-null  uint8
#  9   2           21613 non-null  uint8
#  10  3           21613 non-null  uint8
#  11  4           21613 non-null  uint8
# dtypes: float64(2), int64(5), uint8(5)
# memory usage: 1.3 MB

# %%
X = pd.concat([X, pd.get_dummies(X.view)], axis=1) #manzaranın kalitesi nitel olduğu için dummy değişken olarak ayarlıyoruz.

# %% [markdown]
# Veriyi eğitim ve test alt-veri setlerine ayırma.

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Out:
#   File "<ipython-input-54-c8be1fd528a2>", line 1
#     Veriyi eğitim ve test alt-veri setlerine ayırma.
#            ^
# SyntaxError: invalid syntax
